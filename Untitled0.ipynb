# %% [markdown]
# <a href="https://colab.research.google.com/github/doshak/My_First_Test_Repo/blob/lab2/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd     # для чтения и записи табличных файлов
import numpy as np      # для математической обработки данных
import matplotlib.pyplot as plt # для построения графиков

url = "https://drive.google.com/uc?export=download&id=1VRICeFtVx9dwuTSIDTlVSQzRqQjQVHZU"
input_df = pd.read_csv(url, sep=',', header=None, names=['illuminance'])

print("Заголовок таблицы (имена столбцов):")
print(input_df.columns.tolist())
print("\nПервые 5 строк:")
print(input_df.head())
print("\nПоследние 5 строк:")
print(input_df.tail())

axes = input_df.plot(marker=None, figsize=(20, 20), subplots = True)
# Out:
# Заголовок таблицы (имена столбцов):
# ['illuminance']
#
# Первые 5 строк:
#    illuminance
# 0     39.09334
# 1     37.99574
# 2     39.50392
# 3     40.75022
# 4     37.31230
#
# Последние 5 строк:
#      illuminance
# 995     31.49616
# 996     29.37969
# 997     32.28567
# 998     30.78766
# 999     31.53321
